# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, models
from torchvision.models import vgg19

import os
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
style_image = './Downloads/artistic_style.jpeg'
content_image = './Downloads/dining_table.jpg'

# %%
device = "cpu"

# %%
model = models.vgg19(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /Users/sharduljanaskar/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# HBox(children=(FloatProgress(value=0.0, max=574673361.0), HTML(value='')))

# %%
content = Image.open('./chicago.jpg')
plt.imshow(content)
